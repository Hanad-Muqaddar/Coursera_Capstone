# %%
from pandas.io.json import json_normalize
import json

# %%
with open('report.json', encoding="utf8") as json_data:
    data = json.load(json_data)

# %%
data
# Out:
# {'info': {'added': 1591883448.283499,
#   'started': 1591883448.679997,
#   'duration': 41,
#   'ended': 1591883490.097877,
#   'owner': None,
#   'score': 0.2,
#   'id': 30,
#   'category': 'file',
#   'git': {'head': '13cbe0d9e457be3673304533043e992ead1ea9b2',
#    'fetch_head': '13cbe0d9e457be3673304533043e992ead1ea9b2'},
#   'monitor': '2deb9ccd75d5a7a3fe05b2625b03a8639d6ee36b',
#   'package': 'exe',
#   'route': 'none',
#   'custom': None,
#   'machine': {'status': 'stopped',
#    'name': 'cuckoo',
#    'label': 'cuckoo',
#    'manager': 'VirtualBox',
#    'started_on': '2020-06-11 13:50:49',
#    'shutdown_on': '2020-06-11 13:51:29'},
#   'platform': 'windows',
#   'version': '2.0.7',
#   'options': 'procmemdump=yes,route=none'},
#  'signatures': [{'families': [],
#    'description': 'This executable has a PDB path',
#    'severity': 1,
#    'ttp': {},
#    'markcount': 1,
#    'references': [],
#    'marks': [{'category': 'pdb_path',
# ...

# %%
data['info']
# Out:
# {'added': 1591883448.283499,
#  'started': 1591883448.679997,
#  'duration': 41,
#  'ended': 1591883490.097877,
#  'owner': None,
#  'score': 0.2,
#  'id': 30,
#  'category': 'file',
#  'git': {'head': '13cbe0d9e457be3673304533043e992ead1ea9b2',
#   'fetch_head': '13cbe0d9e457be3673304533043e992ead1ea9b2'},
#  'monitor': '2deb9ccd75d5a7a3fe05b2625b03a8639d6ee36b',
#  'package': 'exe',
#  'route': 'none',
#  'custom': None,
#  'machine': {'status': 'stopped',
#   'name': 'cuckoo',
#   'label': 'cuckoo',
#   'manager': 'VirtualBox',
#   'started_on': '2020-06-11 13:50:49',
#   'shutdown_on': '2020-06-11 13:51:29'},
#  'platform': 'windows',
#  'version': '2.0.7',
#  'options': 'procmemdump=yes,route=none'}

# %%
data['signatures']
# Out:
# [{'families': [],
#   'description': 'This executable has a PDB path',
#   'severity': 1,
#   'ttp': {},
#   'markcount': 1,
#   'references': [],
#   'marks': [{'category': 'pdb_path',
#     'ioc': 'X:\\own\\far\\_far_x64\\Plugins\\Sniffer\\FarSniffer.pdb',
#     'type': 'ioc',
#     'description': None}],
#   'name': 'has_pdb'}]

# %%
data['target']
# Out:
# {'category': 'file',
#  'file': {'yara': [],
#   'sha1': '7de818203be86e0d753f0387e96cf72ac9b61fd3',
#   'name': 'virussign.com_e33d45f608f3fa99981a1af89a887070.vir',
#   'type': 'PE32+ executable (GUI) x86-64, for MS Windows',
#   'sha256': 'df79b47885144c0a85bd50f771bd6efd3fb6a0e6d70cdab78ab677c30db8981c',
#   'urls': [],
#   'crc32': '45ED0E67',
#   'path': '/root/.cuckoo/storage/binaries/df79b47885144c0a85bd50f771bd6efd3fb6a0e6d70cdab78ab677c30db8981c',
#   'ssdeep': None,
#   'size': 5632,
#   'sha512': 'c5895a443bab58d52240787f1bbb955a549da2c62a64341c00ad836b9dd903b306e4973e652c746f9defdd9f1711aeb7cde7358bf8912b7d2d8497152f579f92',
#   'md5': 'e33d45f608f3fa99981a1af89a887070'}}

# %%
data['network']
# Out:
# {'tls': [],
#  'udp': [{'src': '192.168.56.10',
#    'dst': '192.168.56.255',
#    'offset': 836,
#    'time': 3.080275058746338,
#    'dport': 137,
#    'sport': 137},
#   {'src': '192.168.56.10',
#    'dst': '224.0.0.252',
#    'offset': 6096,
#    'time': 2.9648849964141846,
#    'dport': 5355,
#    'sport': 57601},
#   {'src': '192.168.56.10',
#    'dst': '224.0.0.252',
#    'offset': 6424,
#    'time': 3.074249029159546,
#    'dport': 5355,
#    'sport': 57623},
#   {'src': '192.168.56.10',
#    'dst': '224.0.0.252',
#    'offset': 6764,
#    'time': 2.279719114303589,
#    'dport': 5355,
#    'sport': 60478},
#   {'src': '192.168.56.10',
#    'dst': '224.0.0.252',
#    'offset': 7092,
#    'time': 2.5948779582977295,
#    'dport': 5355,
#    'sport': 60955},
#   {'src': '192.168.56.10',
#    'dst': '224.0.0.252',
#    'offset': 7420,
#    'time': 5.517085075378418,
#    'dport': 5355,
#    'sport': 64311},
#   {'src': '192.168.56.10',
#    'dst': '224.0.0.252',
# ...

# %%
data['static']
# Out:
# {'pdb_path': 'X:\\own\\far\\_far_x64\\Plugins\\Sniffer\\FarSniffer.pdb',
#  'pe_imports': [{'imports': [{'name': 'WSACloseEvent',
#      'address': '0x140002080'},
#     {'name': 'ioctlsocket', 'address': '0x140002088'},
#     {'name': 'gethostname', 'address': '0x140002090'},
#     {'name': 'WSAStartup', 'address': '0x140002098'},
#     {'name': 'WSARecv', 'address': '0x1400020a0'},
#     {'name': 'WSAGetLastError', 'address': '0x1400020a8'},
#     {'name': 'WSACleanup', 'address': '0x1400020b0'},
#     {'name': 'bind', 'address': '0x1400020b8'},
#     {'name': 'socket', 'address': '0x1400020c0'},
#     {'name': 'WSAGetOverlappedResult', 'address': '0x1400020c8'},
#     {'name': 'WSACreateEvent', 'address': '0x1400020d0'},
#     {'name': 'closesocket', 'address': '0x1400020d8'},
#     {'name': 'WSAResetEvent', 'address': '0x1400020e0'},
#     {'name': 'gethostbyname', 'address': '0x1400020e8'},
#     {'name': 'WSAStringToAddressW', 'address': '0x1400020f0'},
# ...

# %%
data['debug']
# Out:
# {'action': [],
#  'dbgview': [],
#  'errors': [],
#  'log': ['2020-06-11 10:51:21,565 [analyzer] DEBUG: Starting analyzer from: C:\\tmpbtvcvi\n',
#   '2020-06-11 10:51:21,565 [analyzer] DEBUG: Pipe server name: \\??\\PIPE\\oCkmUSflUxANppRBoANfeoLAXu\n',
#   '2020-06-11 10:51:21,565 [analyzer] DEBUG: Log pipe server name: \\??\\PIPE\\rJLITxcGTZfmnEQkZFENcowdCMDGhf\n',
#   '2020-06-11 10:51:23,142 [analyzer] DEBUG: Started auxiliary module DbgView\n',
#   '2020-06-11 10:51:23,720 [analyzer] DEBUG: Started auxiliary module Disguise\n',
#   "2020-06-11 10:51:25,533 [modules.auxiliary.dumptls] WARNING: You're not running the Cuckoo Agent as Administrator. Doing so will improve your analysis results!\n",
#   '2020-06-11 10:51:25,533 [analyzer] DEBUG: Started auxiliary module DumpTLSMasterSecrets\n',
#   '2020-06-11 10:51:25,533 [analyzer] DEBUG: Started auxiliary module Human\n',
#   '2020-06-11 10:51:25,533 [analyzer] DEBUG: Started auxiliary module InstallCertificate\n',
# ...

# %%
data['strings']
# Out:
# ['!This program cannot be run in DOS mode.',
#  '`.rdata',
#  '@.pdata',
#  '@.rsrc',
#  'create_rule',
#  'RSDS%Y',
#  'X:\\own\\far\\_far_x64\\Plugins\\Sniffer\\FarSniffer.pdb',
#  'WSAWaitForMultipleEvents',
#  'WSAStringToAddressW',
#  'WSAResetEvent',
#  'WSACreateEvent',
#  'WSAGetOverlappedResult',
#  'WSARecv',
#  'WSACloseEvent',
#  'WS2_32.dll',
#  'GetCommandLineW',
#  'FreeLibrary',
#  'GetCurrentProcess',
#  'WriteFile',
#  'LoadLibraryW',
#  'TerminateProcess',
#  'CreateFileW',
#  'lstrcmpW',
#  'GetLastError',
#  'GetProcAddress',
#  'OpenEventW',
#  'CloseHandle',
#  'LocalFree',
#  'KERNEL32.dll',
#  'CommandLineToArgvW',
#  'SHELL32.dll',
#  "<?xml version='1.0' encoding='UTF-8' standalone='yes'?>",
#  "<assembly xmlns='urn:schemas-microsoft-com:asm.v1' manifestVersion='1.0'>",
#  '  <trustInfo xmlns="urn:schemas-microsoft-com:asm.v3">',
#  '    <security>',
#  '      <requestedPrivileges>',
# ...

# %%
data['metadata']
# Out:
# {'output': {'pcap': {'basename': 'dump.pcap',
#    'sha256': 'a89087a6ca3bbdcfdaeb3fe8f5552313c820841ee45fa28a68e5809227e13166',
#    'dirname': ''}}}

# %%
f = open("calls.txt", "r", encoding='UTF-8')
print(f.read())
# Out:
# {
#     "_id" : ObjectId("5f186861a677fd10aae5c9a8"),
#     "pid" : NumberInt(3412),
#     "calls" : [
#         {
#             "category" : "synchronisation",
#             "status" : NumberInt(1),
#             "stacktrace" : [
#
#             ],
#             "api" : "GetSystemTimeAsFileTime",
#             "return_value" : NumberLong(0),
#             "arguments" : {
#
#             },
#             "time" : ISODate("2020-07-23T09:15:21.065+0000"),
#             "tid" : NumberInt(3416),
#             "flags" : {
#
#             }
#         },
#         {
#             "category" : "exception",
#             "status" : NumberInt(0),
#             "stacktrace" : [
#
#             ],
#             "last_error" : NumberInt(0),
#             "nt_status" : NumberInt(-1073741515),
#             "api" : "SetUnhandledExceptionFilter",
#             "return_value" : NumberLong(0),
#             "arguments" : {
#
#             },
# ...

# %%
f.close()

# %%
with open('calls.json', encoding="utf8") as json_data:
    data = json.load(json_data)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-25-11a80e6790db> in <module>
#       1 with open('calls.json', encoding="utf8") as json_data:
# ----> 2     data = json.load(json_data)
#
# ~\Anaconda3\lib\json\__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
# --> 296         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#     297
#     298
#
# ~\Anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# ...
