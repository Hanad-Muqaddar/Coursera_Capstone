# %% [markdown]
# <center><h1> Coursera Capstone Project </h1></center>

# %% [markdown]
# <h1> The Battle of NeighbourHood (Week 1) </h1>

# %%
import pandas as pd
import numpy as np
import time
import json
import requests
from pandas.io.json import json_normalize
from geopy.geocoders import Nominatim
import folium
print("Liberaries Imported")
# Out:
# Liberaries Imported

# %% [markdown]
# <h2> Coursera Capstone - Report Content</h2>
# 1: Introduction Section : ⁃ Discussion of the business problem and the interested audience in this project. <br>
# 2: Data Section:
# ⁃ Description of the data that will be used to solve the problem and the sources. <br>
# 3: Methodology section ⁃ Discussion and description of exploratory data analysis carried out, any inferential statistical <br>
#     testing performed, and if any machine learnings were used establishing the strategy and purposes. <br>
# 4: Results section ⁃ Discussion of the results. <br>
# 5: Discussion section ⁃ Elaboration and discussion on any observations noted and any recommendations suggested based on the<br> results. <br>
# 6: Conclusion section ⁃ Report Conclusion.

# %% [markdown]
# <h1> Introduction Section </h1>

# %% [markdown]
# <h1> Discussion of the business problem and the audience who would be interested in this project. <br> <br>
# Description of the Problem and Background </h1>

# %% [markdown]
# <h1> Scanerio: </h1>

# %% [markdown]
# I am a data scientist residing in Downtown Singapore. I currently live within walking distance to Downtown Telok Ayer MRT metro station and I enjoy many ammenities and venues in the area, such as various international cousine restaurants, cafes, food shops and entertainment. I have been offered a great opportunity to work for a leader firm in Manhattan, NY. I am very excited and I want to use this opportunity to practice my learnings in Coursera in order to answer relevant questions arisen. The key  question is : How can I find a convenient and enjoyable place similar to mine now in Singapore? Certainly, I can use available real estate apps and Google but the idea is to use and apply myself the learned tools during the course. In order to make a comparison and evaluation of the rental options in Manhattan NY, I must set some basis, therefore the apartment in Manhattan must meet the following demands:
#
# <ul>
#     <li>apartment must be 2 or 3 bedrooms</li>
# <li>Desired location is near a metro station in the Manhattan area and within 1.0 mile (1.6 km) radius</li>
# <li>price of rent not exceed $7,000 per month</li>
# <li>Top ammenities in the selected neighborhood shall be similar to current residence</li>
# <li>desirable to have venues such as coffee shops, restaurants, wine stores, gym and food shops.</li>
# <li>as a reference, I have included a map of venues near current residence in Singapore.</li>
#
# </ul>

# %% [markdown]
# # Business Problem:

# %% [markdown]
# The challenge is to find a suitable apartment for rent in Manhattan NY that complies with the demands on location, price and venues.

# %% [markdown]
# #### The data required to resolve this challenge is described in the following section 2, below.

# %% [markdown]
# ### Interested Audience

# %% [markdown]
# I believe this is a relevant challenge with valid questions for anyone moving to other large city in US, EU or Asia. The same methodology can be applied in accordance to demands as applicable. This case is also applicable for anyone interested in exploring starting or locating a new business in any city. Lastly, it can also serve as a good practical exercise to develop Data Science skills.

# %% [markdown]
# # Data Section

# %% [markdown]
# <h1> Description of the Data: </h1>
# The following data is required to answer the issues of the problem:
# <ul>
# <li>List of Boroughs and neighborhoods of Manhattan with their geodata (latitud and longitud)</li>
# <li>List of Subway metro stations in Manhattan with their address location.</li>
# <li>List of apartments for rent in Manhattan area with their addresses and price.</li>
# <li>Preferably, a list of apartment for rent with additional information, such as price, address, area, of beds, etc. </li>
# <li>Venues for each Manhattan neighborhood ( than can be clustered). </li>
# <li>Venues for subway metro stations, as needed. </li>
# </ul>

# %% [markdown]
# <h1> How the data will be used to solve the problem </h1>

# %% [markdown]
# The data will be used as follows:
#     <ul>
#     <li>Use Foursquare and geopy data to map top 10 venues for all Manhattan neighborhoods and clustered in groups ( as per Course LAB)</li>
# <li>Use foursquare and geopy data to map the location of subway metro stations , separately and on top of the above clustered map in order to be able to identify the venues and ammenities near each metro station, or explore each subway location separately.</li>
# <li>Use Foursquare and geopy data to map the location of rental places, in some form, linked to the subway locations.</li>
# <li>create a map that depicts, for instance, the average rental price per square ft, around a radious of 1.0 mile (1.6 km) around each subway station - or a similar metrics. I will be able to quickly point to the popups to know the relative price per subway area.</li>
# <li>Addresses from rental locations will be converted to geodata( lat, long) using Geopy-distance and Nominatim.</li>
# <li>Data will be searched in open data sources if available, from real estate sites if open to reading, libraries or other government agencies such as Metro New York MTA, etc.</li>
#     </ul>

# %% [markdown]
# The procesing of these DATA will allow to answer the key questions to make a decision:

# %% [markdown]
# <ul>
# <li>what is the cost of rent around a mile radius from each subway metro station? </li>
# <li>what is the area of Manhattan with best rental pricing that meets criteria established? </li>
# <li>What is the distance from work place and the tentative future home? </li>
# <li>What are the venues of the two best places to live? How the prices compare? </li>
# <li>How venues distribute among Manhattan neighborhoods and around metro stations? </li>
# <li>Are there tradeoffs between size and price and location. </li>
# <li>Any other interesting statistical data findings of the real estate and overall data.</li>
# </ul>

# %%
address = 'Mccallum Street, Singapore'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Singapore home are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Singapore home are 1.2795465, 103.8476049.

# %%
latitude = 1.2795465
longitude = 103.8476049

# %%
CLIENT_ID = "LPZKC03SV0DGFTMJ1QLKMOJELGJZA5AWCOKQD0A34DMEHW5F"
CLIENT_SECRET = "GGWQ4CTCXQLJNWZYHWI343ONHYQFVVWXWG55W3H0G22XMGUP"
VERSION = "20180605"

# %%
LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 500 # define radius
# create URL
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude, 
    longitude, 
    radius, 
    LIMIT)
url # display URL
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=LPZKC03SV0DGFTMJ1QLKMOJELGJZA5AWCOKQD0A34DMEHW5F&client_secret=GGWQ4CTCXQLJNWZYHWI343ONHYQFVVWXWG55W3H0G22XMGUP&v=20180605&ll=1.2795465,103.8476049&radius=500&limit=100'

# %%
results = requests.get(url).json()

# %%
results
# Out:
# {'meta': {'code': 200, 'requestId': '5f1dd804588ea57d02d5559a'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Financial District',
#   'headerFullLocation': 'Financial District, Singapore',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 178,
#   'suggestedBounds': {'ne': {'lat': 1.2840465045000045,
#     'lng': 103.8520976227615},
#    'sw': {'lat': 1.2750464954999954, 'lng': 103.84311217723848}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51b49e49abd88dd0b4e7330f',
#        'name': 'Napoleon Food & Wine Bar',
#        'location': {'address': '206 Telok Ayer Street',
#         'lat': 1.2799249387439204,
#         'lng': 103.84733300574288,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2799249387439204,
#           'lng': 103.84733300574288}],
#         'distance': 51,
#         'postalCode': '068641',
#         'cc': 'SG',
#         'neighborhood': 'Tanjong Pagar',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['206 Telok Ayer Street', '068641', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d123941735',
#          'name': 'Wine Bar',
#          'pluralName': 'Wine Bars',
#          'shortName': 'Wine Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/winery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '58378307'}},
#       'referralId': 'e-0-51b49e49abd88dd0b4e7330f-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '586a792404aa4f25645e4e4e',
#        'name': 'Native',
#        'location': {'address': '52A Amoy Street',
#         'lat': 1.2801354244146959,
#         'lng': 103.84684430802805,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2801354244146959,
#           'lng': 103.84684430802805}],
#         'distance': 107,
#         'postalCode': '069878',
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['52A Amoy Street', '069878', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d11e941735',
#          'name': 'Cocktail Bar',
#          'pluralName': 'Cocktail Bars',
#          'shortName': 'Cocktail',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-586a792404aa4f25645e4e4e-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50248ddde4b0bb3db3a6ff8a',
#        'name': 'Pepper Bowl',
#        'location': {'address': '#02-102, Amoy Street Food Centre',
#         'crossStreet': '7 Maxwell Rd.',
#         'lat': 1.279371,
#         'lng': 103.84671,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.279371,
#           'lng': 103.84671}],
#         'distance': 101,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#02-102, Amoy Street Food Centre (7 Maxwell Rd.)',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d142941735',
#          'name': 'Asian Restaurant',
#          'pluralName': 'Asian Restaurants',
#          'shortName': 'Asian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50248ddde4b0bb3db3a6ff8a-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55a49050498e801fbf03be73',
#        'name': 'Park Bench Deli',
#        'location': {'address': '179 Telok Ayer St',
#         'crossStreet': 'Amoy St',
#         'lat': 1.2798723608759432,
#         'lng': 103.84728710112705,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2798723608759432,
#           'lng': 103.84728710112705}],
#         'distance': 50,
#         'postalCode': '068627',
#         'cc': 'SG',
#         'neighborhood': 'Chinatown',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['179 Telok Ayer St (Amoy St)',
#          '068627',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d146941735',
#          'name': 'Deli / Bodega',
#          'pluralName': 'Delis / Bodegas',
#          'shortName': 'Deli / Bodega',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55a49050498e801fbf03be73-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56e9512acd10cabb2f042d09',
#        'name': 'Freehouse',
#        'location': {'address': '21A Boon Tat Street',
#         'lat': 1.2812544915596238,
#         'lng': 103.8485128808929,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2812544915596238,
#           'lng': 103.8485128808929}],
#         'distance': 215,
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['21A Boon Tat Street', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d117941735',
#          'name': 'Beer Garden',
#          'pluralName': 'Beer Gardens',
#          'shortName': 'Beer Garden',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/beergarden_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56e9512acd10cabb2f042d09-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c57877d6201e21e49b7e86e',
#        'name': 'PS.Cafe',
#        'location': {'address': '45 Ann Siang Hill #02-02',
#         'crossStreet': 'Ann Siang Hill Park',
#         'lat': 1.2804684376763578,
#         'lng': 103.8462642876152,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2804684376763578,
#           'lng': 103.8462642876152}],
#         'distance': 181,
#         'postalCode': '069719',
#         'cc': 'SG',
#         'neighborhood': 'Chinatown',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['45 Ann Siang Hill #02-02 (Ann Siang Hill Park)',
#          '069719',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c57877d6201e21e49b7e86e-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '553b2460498e8cfc0a3cdc32',
#        'name': 'Yen Yakiniku',
#        'location': {'address': '15 Ann Siang Road',
#         'lat': 1.2810744259693214,
#         'lng': 103.84574260981839,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2810744259693214,
#           'lng': 103.84574260981839}],
#         'distance': 268,
#         'postalCode': '069695',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['15 Ann Siang Road', '069695', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'shortName': 'Japanese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-553b2460498e8cfc0a3cdc32-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e5e1aefe4cdfc603ed5c7c3',
#        'name': '왕대박 Wang Dae Bak Korean BBQ Restaurant',
#        'location': {'address': '98 Amoy St',
#         'lat': 1.281345203093981,
#         'lng': 103.84755092069813,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.281345203093981,
#           'lng': 103.84755092069813}],
#         'distance': 200,
#         'postalCode': '069918',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['98 Amoy St', '069918', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d113941735',
#          'name': 'Korean Restaurant',
#          'pluralName': 'Korean Restaurants',
#          'shortName': 'Korean',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e5e1aefe4cdfc603ed5c7c3-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56ecb93dcd101850ebc08dc5',
#        'name': 'Mellower Coffee',
#        'location': {'address': '77 Robinson Road #01-03',
#         'lat': 1.2778141065087054,
#         'lng': 103.84818781617354,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2778141065087054,
#           'lng': 103.84818781617354}],
#         'distance': 203,
#         'postalCode': '068896',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['77 Robinson Road #01-03',
#          '068896',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56ecb93dcd101850ebc08dc5-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e741c8baeb780be09a0321f',
#        'name': 'Sarnies',
#        'location': {'address': '136 Telok Ayer St',
#         'lat': 1.2815286862041824,
#         'lng': 103.84811698897273,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2815286862041824,
#           'lng': 103.84811698897273}],
#         'distance': 227,
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['136 Telok Ayer St', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'shortName': 'Sandwiches',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e741c8baeb780be09a0321f-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54e975f6498e0c8bb883ee29',
#        'name': 'Meat Smith',
#        'location': {'address': '167 Telok Ayer Street',
#         'lat': 1.2802049410855447,
#         'lng': 103.8474104901937,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2802049410855447,
#           'lng': 103.8474104901937}],
#         'distance': 76,
#         'postalCode': '068620',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['167 Telok Ayer Street', '068620', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d14f941735',
#          'name': 'Southern / Soul Food Restaurant',
#          'pluralName': 'Southern / Soul Food Restaurants',
#          'shortName': 'Southern / Soul',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/southern_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '219625364'}},
#       'referralId': 'e-0-54e975f6498e0c8bb883ee29-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '557a6b3c498ed9cb15987433',
#        'name': 'ShuKuu Izakaya',
#        'location': {'address': '8 Stanley Street',
#         'lat': 1.280110799343203,
#         'lng': 103.8477615067585,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.280110799343203,
#           'lng': 103.8477615067585}],
#         'distance': 65,
#         'postalCode': '068727',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['8 Stanley Street', '068727', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'shortName': 'Japanese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-557a6b3c498ed9cb15987433-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f704af9e4b07a4bc6edd2a9',
#        'name': 'Sofitel So Singapore',
#        'location': {'address': '35 Robinson Road',
#         'lat': 1.280016815397146,
#         'lng': 103.84981314280776,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.280016815397146,
#           'lng': 103.84981314280776}],
#         'distance': 251,
#         'postalCode': '068876',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['35 Robinson Road', '068876', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '150895632'}},
#       'referralId': 'e-0-4f704af9e4b07a4bc6edd2a9-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '58181cfd38fa17eb24ba32fa',
#        'name': 'Virgin Active',
#        'location': {'address': '#06-01 Guoco Tower',
#         'crossStreet': '7 Wallich Street',
#         'lat': 1.2770546200166835,
#         'lng': 103.84643542061019,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2770546200166835,
#           'lng': 103.84643542061019}],
#         'distance': 306,
#         'postalCode': '078884',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#06-01 Guoco Tower (7 Wallich Street)',
#          '078884',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'shortName': 'Gym / Fitness',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-58181cfd38fa17eb24ba32fa-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53db460f498e18a343d830db',
#        'name': 'Pantler',
#        'location': {'address': '198 Telok Ayer St',
#         'lat': 1.280137,
#         'lng': 103.847256,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.280137,
#           'lng': 103.847256}],
#         'distance': 76,
#         'postalCode': '068637',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['198 Telok Ayer St', '068637', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53db460f498e18a343d830db-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '543e53f6498e8eacbba09d5e',
#        'name': 'Oven & Fried Chicken',
#        'location': {'address': '182 Telok Ayer Street',
#         'lat': 1.280479036515832,
#         'lng': 103.84752160405156,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.280479036515832,
#           'lng': 103.84752160405156}],
#         'distance': 104,
#         'postalCode': '068630',
#         'cc': 'SG',
#         'neighborhood': 'Chinatown',
#         'country': 'Singapore',
#         'formattedAddress': ['182 Telok Ayer Street', '068630', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d113941735',
#          'name': 'Korean Restaurant',
#          'pluralName': 'Korean Restaurants',
#          'shortName': 'Korean',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-543e53f6498e8eacbba09d5e-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '506daac8e4b09e74d871828c',
#        'name': 'Lolla',
#        'location': {'address': '22 Ann Siang Hill',
#         'crossStreet': 'Ann Siang Road',
#         'lat': 1.2810338519455675,
#         'lng': 103.84570753754707,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2810338519455675,
#           'lng': 103.84570753754707}],
#         'distance': 268,
#         'postalCode': '069702',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['22 Ann Siang Hill (Ann Siang Road)',
#          '069702',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-506daac8e4b09e74d871828c-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b6a6236f964a5200fd42be3',
#        'name': 'Coffee Break',
#        'location': {'address': '#02-78 Amoy Street Food Centre',
#         'crossStreet': '7 Maxwell Road',
#         'lat': 1.2795293,
#         'lng': 103.846695,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2795293,
#           'lng': 103.846695}],
#         'distance': 101,
#         'postalCode': '069111',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#02-78 Amoy Street Food Centre (7 Maxwell Road)',
#          '069111',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b6a6236f964a5200fd42be3-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d24773df39ca14334e675b8',
#        'name': 'Quan Ji @ Amoy Street Food Market',
#        'location': {'address': '#01-56/57 7 Maxwell Road',
#         'lat': 1.2791000736241216,
#         'lng': 103.84739222011355,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2791000736241216,
#           'lng': 103.84739222011355}],
#         'distance': 55,
#         'postalCode': '069111',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-56/57 7 Maxwell Road',
#          '069111',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'shortName': 'Chinese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d24773df39ca14334e675b8-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5ba8e7638b98fd002c7c2b1f',
#        'name': 'Dumpling Darlings',
#        'location': {'address': '44 Amoy Street',
#         'lat': 1.2804831833097174,
#         'lng': 103.84694151071514,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2804831833097174,
#           'lng': 103.84694151071514}],
#         'distance': 127,
#         'postalCode': '069870',
#         'cc': 'SG',
#         'neighborhood': 'Chinatown',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['44 Amoy Street', '069870', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d108941735',
#          'name': 'Dumpling Restaurant',
#          'pluralName': 'Dumpling Restaurants',
#          'shortName': 'Dumplings',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dumplings_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5ba8e7638b98fd002c7c2b1f-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56d3c557cd10357fe7eb429e',
#        'name': 'Magal BBQ 마포갈매기',
#        'location': {'address': '123 Telok Ayer Street',
#         'lat': 1.2812992606038325,
#         'lng': 103.84793164085784,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2812992606038325,
#           'lng': 103.84793164085784}],
#         'distance': 198,
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['123 Telok Ayer Street', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d113941735',
#          'name': 'Korean Restaurant',
#          'pluralName': 'Korean Restaurants',
#          'shortName': 'Korean',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56d3c557cd10357fe7eb429e-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b05880bf964a520eaad22e3',
#        'name': 'The Scarlet',
#        'location': {'address': '33 Erskine Road',
#         'lat': 1.2807069667371653,
#         'lng': 103.84543116452546,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2807069667371653,
#           'lng': 103.84543116452546}],
#         'distance': 274,
#         'postalCode': '069333',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['33 Erskine Road', '069333', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b05880bf964a520eaad22e3-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '551bd574498e5f30136a811e',
#        'name': 'FYR Cycene Ond Drinc',
#        'location': {'address': '19 Boon Tat Street',
#         'lat': 1.2812964408600642,
#         'lng': 103.8484369192239,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2812964408600642,
#           'lng': 103.8484369192239}],
#         'distance': 215,
#         'postalCode': '069619',
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['19 Boon Tat Street', '069619', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-551bd574498e5f30136a811e-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4df741991f6e94c2c77ef6da',
#        'name': "Luke's Oyster Bar & Chop House",
#        'location': {'address': '20 Gemmill Lane',
#         'lat': 1.2824588279356128,
#         'lng': 103.84724044318698,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2824588279356128,
#           'lng': 103.84724044318698}],
#         'distance': 326,
#         'postalCode': '069256',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['20 Gemmill Lane', '069256', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1ce941735',
#          'name': 'Seafood Restaurant',
#          'pluralName': 'Seafood Restaurants',
#          'shortName': 'Seafood',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4df741991f6e94c2c77ef6da-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fc8aecee4b08eb1f57a1a81',
#        'name': 'Anglo Indian Cafe & Bar',
#        'location': {'address': '1 Shenton Way',
#         'lat': 1.2790836483039665,
#         'lng': 103.85012677894278,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2790836483039665,
#           'lng': 103.85012677894278}],
#         'distance': 285,
#         'postalCode': '068803',
#         'cc': 'SG',
#         'neighborhood': 'Financial District',
#         'country': 'Singapore',
#         'formattedAddress': ['1 Shenton Way', '068803', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'shortName': 'Indian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4fc8aecee4b08eb1f57a1a81-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52c54d0411d2a3d73dae49f6',
#        'name': 'Lau Pa Sat Satay Street',
#        'location': {'address': 'Boon Tat Street',
#         'lat': 1.280261,
#         'lng': 103.850235,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.280261,
#           'lng': 103.850235}],
#         'distance': 303,
#         'postalCode': '048582',
#         'cc': 'SG',
#         'neighborhood': 'Financial District',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Boon Tat Street', '048582', 'Singapore']},
#        'categories': [{'id': '53e0feef498e5aac066fd8a9',
#          'name': 'Street Food Gathering',
#          'pluralName': 'Street Food Gatherings',
#          'shortName': 'Street Food Gathering',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-52c54d0411d2a3d73dae49f6-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5beed4bb9411f20038c1f8f8',
#        'name': 'The Other Roof',
#        'location': {'address': '28 Ann Siang Road',
#         'lat': 1.28083,
#         'lng': 103.845763,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.28083,
#           'lng': 103.845763}],
#         'distance': 249,
#         'postalCode': '069708',
#         'cc': 'SG',
#         'neighborhood': 'Chinatown',
#         'city': 'Tanjong Pagar',
#         'state': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['28 Ann Siang Road', '069708', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5beed4bb9411f20038c1f8f8-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51407e7fe4b084291b552e1d',
#        'name': 'The Spiffy Dapper',
#        'location': {'address': '73 Amoy St, Second Floor',
#         'lat': 1.280207345376872,
#         'lng': 103.84686000197097,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.280207345376872,
#           'lng': 103.84686000197097}],
#         'distance': 110,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['73 Amoy St, Second Floor', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d11e941735',
#          'name': 'Cocktail Bar',
#          'pluralName': 'Cocktail Bars',
#          'shortName': 'Cocktail',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '51342112'}},
#       'referralId': 'e-0-51407e7fe4b084291b552e1d-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5a25322142d8c2528e5b178a',
#        'name': 'Myo Restobar',
#        'location': {'address': '138 Robinson Road #19-01',
#         'crossStreet': 'Oxley Tower',
#         'lat': 1.278826,
#         'lng': 103.848354,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.278826,
#           'lng': 103.848354}],
#         'distance': 115,
#         'postalCode': '068906',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['138 Robinson Road #19-01 (Oxley Tower)',
#          '068906',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d147941735',
#          'name': 'Diner',
#          'pluralName': 'Diners',
#          'shortName': 'Diner',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5a25322142d8c2528e5b178a-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5bab10b9364d97002cc5e458',
#        'name': 'Muchachos',
#        'location': {'address': '#01-01 Frasers Tower',
#         'crossStreet': '182 Cecil Street',
#         'lat': 1.2790721332821124,
#         'lng': 103.84702556749504,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2790721332821124,
#           'lng': 103.84702556749504}],
#         'distance': 83,
#         'postalCode': '069547',
#         'cc': 'SG',
#         'neighborhood': 'Financial District',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-01 Frasers Tower (182 Cecil Street)',
#          '069547',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d153941735',
#          'name': 'Burrito Place',
#          'pluralName': 'Burrito Places',
#          'shortName': 'Burritos',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burrito_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5bab10b9364d97002cc5e458-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b305537f964a520fef824e3',
#        'name': 'Amoy Street Food Centre',
#        'location': {'address': '7 Maxwell Rd',
#         'crossStreet': 'Telok Ayer St / Amoy St',
#         'lat': 1.2795923,
#         'lng': 103.8467,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2795923,
#           'lng': 103.8467}],
#         'distance': 100,
#         'postalCode': '069111',
#         'cc': 'SG',
#         'neighborhood': 'Financial District',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['7 Maxwell Rd (Telok Ayer St / Amoy St)',
#          '069111',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d120951735',
#          'name': 'Food Court',
#          'pluralName': 'Food Courts',
#          'shortName': 'Food Court',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b305537f964a520fef824e3-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51245408e4b07c9613693ff3',
#        'name': 'The Flying Squirrel',
#        'location': {'address': '92 Amoy Street #01-02',
#         'lat': 1.2812406376693863,
#         'lng': 103.8471001202725,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2812406376693863,
#           'lng': 103.8471001202725}],
#         'distance': 196,
#         'postalCode': '069911',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['92 Amoy Street #01-02', '069911', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'shortName': 'Japanese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51245408e4b07c9613693ff3-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d53753b5c9d236a282bf3ce',
#        'name': 'Otto Ristorante Italiano',
#        'location': {'address': '#01-02 Red Dot Traffic Building',
#         'lat': 1.2779313695606225,
#         'lng': 103.84613475409516,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2779313695606225,
#           'lng': 103.84613475409516}],
#         'distance': 243,
#         'postalCode': '069115',
#         'cc': 'SG',
#         'neighborhood': 'Tanjong Pagar',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-02 Red Dot Traffic Building',
#          '069115',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d53753b5c9d236a282bf3ce-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5580f23c498ed3f5a3270457',
#        'name': "Wanton Seng's Noodle Bar",
#        'location': {'address': '52 Amoy Street',
#         'lat': 1.2801395970080391,
#         'lng': 103.84683438697066,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2801395970080391,
#           'lng': 103.84683438697066}],
#         'distance': 108,
#         'postalCode': '069878',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['52 Amoy Street', '069878', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1d1941735',
#          'name': 'Noodle House',
#          'pluralName': 'Noodle Houses',
#          'shortName': 'Noodles',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5580f23c498ed3f5a3270457-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56c5ad91cd10c0576881c9f7',
#        'name': 'Cheek Bistro',
#        'location': {'address': '21 Boon Tat Street',
#         'lat': 1.2811976258854165,
#         'lng': 103.84850410058729,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2811976258854165,
#           'lng': 103.84850410058729}],
#         'distance': 209,
#         'postalCode': '069620',
#         'cc': 'SG',
#         'neighborhood': 'Chinatown',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['21 Boon Tat Street', '069620', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d169941735',
#          'name': 'Australian Restaurant',
#          'pluralName': 'Australian Restaurants',
#          'shortName': 'Australian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/australian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56c5ad91cd10c0576881c9f7-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b2f5ccef964a520f3ea24e3',
#        'name': 'Ann Siang Hill',
#        'location': {'address': 'Ann Siang Road',
#         'crossStreet': 'Ann Siang Road',
#         'lat': 1.2815049423709581,
#         'lng': 103.84549022833018,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2815049423709581,
#           'lng': 103.84549022833018}],
#         'distance': 320,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Ann Siang Road (Ann Siang Road)', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d162941735',
#          'name': 'Other Great Outdoors',
#          'pluralName': 'Other Great Outdoors',
#          'shortName': 'Other Outdoors',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/outdoors_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b2f5ccef964a520f3ea24e3-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ca579c7d971b1f7593ef7e0',
#        'name': 'Han Kee Fish Soup',
#        'location': {'address': '#02-129, Amoy Street Food Centre',
#         'crossStreet': '7 Maxwell Road',
#         'lat': 1.2794006,
#         'lng': 103.846596,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2794006,
#           'lng': 103.846596}],
#         'distance': 113,
#         'postalCode': '069111',
#         'cc': 'SG',
#         'neighborhood': 'Financial District',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#02-129, Amoy Street Food Centre (7 Maxwell Road)',
#          '069111',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1dd931735',
#          'name': 'Soup Place',
#          'pluralName': 'Soup Places',
#          'shortName': 'Soup',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/soup_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ca579c7d971b1f7593ef7e0-36'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d3913bab5abb1f75c13e498',
#        'name': "No Menu Italian Family's Kitchen",
#        'location': {'address': '21A-23A Boon Tat Street',
#         'lat': 1.2812104540226847,
#         'lng': 103.84847352065823,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2812104540226847,
#           'lng': 103.84847352065823}],
#         'distance': 208,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['21A-23A Boon Tat Street', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d3913bab5abb1f75c13e498-37'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5550d029498ece2b65824efd',
#        'name': 'Hyang Yeon (향연)',
#        'location': {'address': '#01-01 80 Amoy Street',
#         'lat': 1.2805355867345907,
#         'lng': 103.84690264038922,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2805355867345907,
#           'lng': 103.84690264038922}],
#         'distance': 135,
#         'postalCode': '069899',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-01 80 Amoy Street', '069899', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d113941735',
#          'name': 'Korean Restaurant',
#          'pluralName': 'Korean Restaurants',
#          'shortName': 'Korean',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5550d029498ece2b65824efd-38'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d08478ec26ba143728f1817',
#        'name': '6oz Espresso Bar',
#        'location': {'address': '#01-K1, Tokio Marine Centre',
#         'crossStreet': '20 McCallum St',
#         'lat': 1.279543363638627,
#         'lng': 103.84803324937819,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.279543363638627,
#           'lng': 103.84803324937819}],
#         'distance': 47,
#         'postalCode': '069046',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-K1, Tokio Marine Centre (20 McCallum St)',
#          '069046',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d08478ec26ba143728f1817-39'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5a3cedd52619ee7032f8903c',
#        'name': 'Blue Label',
#        'location': {'address': '28 Ann Siang Road B1',
#         'lat': 1.2808603852749922,
#         'lng': 103.84578798136066,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2808603852749922,
#           'lng': 103.84578798136066}],
#         'distance': 249,
#         'postalCode': '069708',
#         'cc': 'SG',
#         'neighborhood': 'Financial District',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['28 Ann Siang Road B1', '069708', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5a3cedd52619ee7032f8903c-40'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57642221498edc75f496b1d7',
#        'name': 'Employees Only Singapore',
#        'location': {'address': '112 Amoy Street',
#         'lat': 1.282049921616686,
#         'lng': 103.84776961431051,
# ...
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '58bf8f1965be586aa82fe98b',
#        'name': 'Henri Charpentier',
#        'location': {'address': 'Tanjong Pagar Centre Level B2',
#         'lat': 1.2769868762612466,
#         'lng': 103.84535147421906,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2769868762612466,
#           'lng': 103.84535147421906}],
#         'distance': 379,
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['Tanjong Pagar Centre Level B2', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-58bf8f1965be586aa82fe98b-86'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51a49cd7498e45605109bc28',
#        'name': 'Yoga Movement',
#        'location': {'address': '21 Tanjong Pagar Rd',
#         'crossStreet': 'Murray St',
#         'lat': 1.279561008004445,
#         'lng': 103.84402560835365,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.279561008004445,
#           'lng': 103.84402560835365}],
#         'distance': 398,
#         'postalCode': '088444',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['21 Tanjong Pagar Rd (Murray St)',
#          '088444',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'shortName': 'Yoga Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51a49cd7498e45605109bc28-87'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '509e78c4e4b01b9e499cf2a5',
#        'name': 'Adler Hostel',
#        'location': {'address': 'South Bridge Road',
#         'crossStreet': '259 South Bridge Road',
#         'lat': 1.2822552089491077,
#         'lng': 103.84521682292143,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2822552089491077,
#           'lng': 103.84521682292143}],
#         'distance': 401,
#         'postalCode': '58808',
#         'cc': 'SG',
#         'city': 'Chinatown',
#         'country': 'Singapore',
#         'formattedAddress': ['South Bridge Road (259 South Bridge Road)',
#          '58808',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1ee931735',
#          'name': 'Hostel',
#          'pluralName': 'Hostels',
#          'shortName': 'Hostel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hostel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '77554945'}},
#       'referralId': 'e-0-509e78c4e4b01b9e499cf2a5-88'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b625e08f964a5208f442ae3',
#        'name': 'EvolveMMA Far East Square',
#        'location': {'address': '26 China Street, #01-01',
#         'crossStreet': 'Cross Street',
#         'lat': 1.2829673982020517,
#         'lng': 103.84806217253097,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2829673982020517,
#           'lng': 103.84806217253097}],
#         'distance': 384,
#         'postalCode': '049568',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['26 China Street, #01-01 (Cross Street)',
#          '049568',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d101941735',
#          'name': 'Martial Arts Dojo',
#          'pluralName': 'Martial Arts Dojos',
#          'shortName': 'Martial Arts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_martialarts_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b625e08f964a5208f442ae3-89'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54b4a4ec498ee0d307d4bbce',
#        'name': 'Katanashi An',
#        'location': {'address': '1 Boon Tat Street #01-01',
#         'lat': 1.2816673336385689,
#         'lng': 103.8477117574702,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2816673336385689,
#           'lng': 103.8477117574702}],
#         'distance': 236,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['1 Boon Tat Street #01-01', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'shortName': 'Japanese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-54b4a4ec498ee0d307d4bbce-90'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5657c0cd498e5e36dd8dcd9a',
#        'name': 'Free the Robot',
#        'location': {'address': '118 Telok Ayer Street',
#         'lat': 1.2819218886879917,
#         'lng': 103.84817808866501,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2819218886879917,
#           'lng': 103.84817808866501}],
#         'distance': 272,
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['118 Telok Ayer Street', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5657c0cd498e5e36dd8dcd9a-91'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5625d21a498e596424dac931',
#        'name': 'Joe & Dough',
#        'location': {'address': '#36-01 Capital Tower, 168 Robinson Road',
#         'lat': 1.2777145899465967,
#         'lng': 103.84761868252289,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2777145899465967,
#           'lng': 103.84761868252289}],
#         'distance': 203,
#         'postalCode': '068912',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#36-01 Capital Tower, 168 Robinson Road',
#          '068912',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5625d21a498e596424dac931-92'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5925348c747ecd3652b7fc31',
#        'name': 'Downtown Gallery',
#        'location': {'address': '6A Shenton Way',
#         'lat': 1.276451814240619,
#         'lng': 103.8484626777089,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.276451814240619,
#           'lng': 103.8484626777089}],
#         'distance': 357,
#         'postalCode': '068815',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['6A Shenton Way', '068815', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1fd941735',
#          'name': 'Shopping Mall',
#          'pluralName': 'Shopping Malls',
#          'shortName': 'Mall',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5925348c747ecd3652b7fc31-93'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cac0f2176d3a0938db32e6b',
#        'name': 'Littered With Books',
#        'location': {'address': '20 Duxton Rd',
#         'lat': 1.2794401610962218,
#         'lng': 103.84332770263443,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2794401610962218,
#           'lng': 103.84332770263443}],
#         'distance': 476,
#         'postalCode': '089486',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['20 Duxton Rd', '089486', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d114951735',
#          'name': 'Bookstore',
#          'pluralName': 'Bookstores',
#          'shortName': 'Bookstore',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cac0f2176d3a0938db32e6b-94'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '58255545b244c8385714dd29',
#        'name': 'The Daily Cut',
#        'location': {'address': '#B2-16 Guoco Tower',
#         'crossStreet': '7 Wallich Street',
#         'lat': 1.2767265621171775,
#         'lng': 103.8452612818406,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2767265621171775,
#           'lng': 103.8452612818406}],
#         'distance': 408,
#         'postalCode': '078884',
#         'cc': 'SG',
#         'city': 'Tanjong Pagar',
#         'state': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#B2-16 Guoco Tower (7 Wallich Street)',
#          '078884',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1bd941735',
#          'name': 'Salad Place',
#          'pluralName': 'Salad Places',
#          'shortName': 'Salad',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/salad_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-58255545b244c8385714dd29-95'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '528499ae11d2f90239dcd477',
#        'name': 'Westin Infinity Pool',
#        'location': {'address': 'L35, Asia Square Tower 2',
#         'crossStreet': '12 Marina View',
#         'lat': 1.2780572315130252,
#         'lng': 103.8510768539789,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2780572315130252,
#           'lng': 103.8510768539789}],
#         'distance': 420,
#         'postalCode': '018961',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['L35, Asia Square Tower 2 (12 Marina View)',
#          '018961',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d15e941735',
#          'name': 'Pool',
#          'pluralName': 'Pools',
#          'shortName': 'Pool',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-528499ae11d2f90239dcd477-96'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '592033c1f96b2c5570007df6',
#        'name': 'En Sakaba',
#        'location': {'address': 'Capital Tower #01-10',
#         'lat': 1.2770746709229392,
#         'lng': 103.84757986038572,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2770746709229392,
#           'lng': 103.84757986038572}],
#         'distance': 275,
#         'postalCode': '068912',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Capital Tower #01-10', '068912', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1d2941735',
#          'name': 'Sushi Restaurant',
#          'pluralName': 'Sushi Restaurants',
#          'shortName': 'Sushi',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-592033c1f96b2c5570007df6-97'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50cc3cb1e4b05e0e4cf5bf94',
#        'name': 'Healthland Pte Ltd',
#        'location': {'address': '252A South Bridge Road',
#         'lat': 1.2822897974440162,
#         'lng': 103.84516609436308,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2822897974440162,
#           'lng': 103.84516609436308}],
#         'distance': 408,
#         'postalCode': '058801',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['252A South Bridge Road', '058801', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1ed941735',
#          'name': 'Spa',
#          'pluralName': 'Spas',
#          'shortName': 'Spa',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50cc3cb1e4b05e0e4cf5bf94-98'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5887008018dc5375de1b11e0',
#        'name': 'Kuro Maguro',
#        'location': {'address': '7 Wallich Street, #01-04 Tanjong Pagar Centre',
#         'lat': 1.2766989535948103,
#         'lng': 103.8459509163215,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2766989535948103,
#           'lng': 103.8459509163215}],
#         'distance': 366,
#         'postalCode': '078884',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['7 Wallich Street, #01-04 Tanjong Pagar Centre',
#          '078884',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'shortName': 'Japanese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5887008018dc5375de1b11e0-99'}]}]}}

# %%
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = results['response']['groups'][0]['items']
SGnearby_venues = json_normalize(venues) # flatten JSON
# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
SGnearby_venues =SGnearby_venues.loc[:, filtered_columns]
# # filter the category for each row
SGnearby_venues['venue.categories'] = SGnearby_venues.apply(get_category_type, axis=1)
SGnearby_venues.columns
# # clean columns
SGnearby_venues.columns = [col.split(".")[-1]for col in SGnearby_venues.columns]
SGnearby_venues
SGnearby_venues.shape
# Out:
# C:\Users\syedh\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
# (100, 4)

# %%
SGnearby_venues.head(5)
# Out:
#                        name        categories       lat         lng
# 0  Napoleon Food & Wine Bar          Wine Bar  1.279925  103.847333
# 1                    Native      Cocktail Bar  1.280135  103.846844
# 2               Pepper Bowl  Asian Restaurant  1.279371  103.846710
# 3           Park Bench Deli     Deli / Bodega  1.279872  103.847287
# 4                 Freehouse       Beer Garden  1.281254  103.848513

# %%
latitude=1.2792655
longitude=103.8480938
# create map of Singapore place  using latitude and longitude values
map_sg = folium.Map(location=[latitude, longitude], zoom_start=18)
# add markers to map
for lat, lng, label in zip(SGnearby_venues['lat'], SGnearby_venues['lng'], SGnearby_venues['name']):
    label = folium.Popup(label, parse_html=True)
    folium.RegularPolygonMarker(
        [lat, lng],
        number_of_sides=30,
        radius=7,
        popup=label,
        color='blue',
        fill_color='#0f0f0f',
        fill_opacity=0.6,
    ).add_to(map_sg)  
    
map_sg
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
